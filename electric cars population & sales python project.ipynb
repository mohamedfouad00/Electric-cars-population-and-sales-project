# %% [markdown]
# # Electric cars population project

# %% [markdown]
# <mm>

# %% [markdown]
# ## 1. Data wrangling and preparation

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.1 Import and read data

# %% [markdown]
# <m>

# %%
import pandas as pd
import numpy as np
import janitor as janitor
import missingno as msno
import matplotlib.pyplot as plt 
import seaborn as sns 
import sweetviz as sv
from scipy import stats
import statsmodels.api as sm
from statsmodels.api import OLS
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
import openpyxl
import pyarrow
import re
from fuzzywuzzy import fuzz, process
import geopandas as gpd
import warnings as warnings
warnings.filterwarnings('ignore')
plt.style.use('ggplot')
# %matplotlib inline

# %%
df=pd.read_csv('Electric viechle population.csv')

# %%
df.head(10)
# Out:
#    VIN (1-10)     County         City State  Postal Code  Model Year  \
# 0  KM8K33AGXL       King      Seattle    WA      98103.0        2020
# 1  1C4RJYB61N       King      Bothell    WA      98011.0        2022
# 2  1C4RJYD61P     Yakima       Yakima    WA      98908.0        2023
# 3  5YJ3E1EA7J       King     Kirkland    WA      98034.0        2018
# 4  WBY7Z8C5XJ   Thurston      Olympia    WA      98501.0        2018
# 5  5YJ3E1EAXL  Snohomish   Marysville    WA      98271.0        2020
# 6  2C4RC1N77H       King         Kent    WA      98042.0        2017
# 7  5YJYGDEE3L       King  Woodinville    WA      98072.0        2020
# 8  5YJ3E1EA1J     Island   Coupeville    WA      98239.0        2018
# 9  7SAYGDEF0P       King     Bellevue    WA      98004.0        2023
#
#        Make           Model                   Electric Vehicle Type  \
# 0   HYUNDAI            KONA          Battery Electric Vehicle (BEV)
# 1      JEEP  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2      JEEP  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3     TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 4       BMW              I3  Plug-in Hybrid Electric Vehicle (PHEV)
# 5     TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 6  CHRYSLER        PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 7     TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 8     TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 9     TESLA         MODEL Y          Battery Electric Vehicle (BEV)
#
#    Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0            Clean Alternative Fuel Vehicle Eligible             258
# 1              Not eligible due to low battery range              25
# 2              Not eligible due to low battery range              25
# 3            Clean Alternative Fuel Vehicle Eligible             215
# 4            Clean Alternative Fuel Vehicle Eligible              97
# 5            Clean Alternative Fuel Vehicle Eligible             266
# 6            Clean Alternative Fuel Vehicle Eligible              33
# 7            Clean Alternative Fuel Vehicle Eligible             291
# 8            Clean Alternative Fuel Vehicle Eligible             215
# 9  Eligibility unknown as battery range has not b...               0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  43.0       249675142
# 1          0                   1.0       233928502
# 2          0                  14.0       229675939
# 3          0                  45.0       104714466
# 4          0                  22.0       185498386
# 5          0                  38.0       124595523
# 6          0                  47.0         1815593
# 7          0                  45.0       124760555
# 8          0                  10.0       125048003
# 9          0                  48.0       240416207
#
#                   Vehicle Location  \
# 0     POINT (-122.34301 47.659185)
# 1     POINT (-122.20578 47.762405)
# 2  POINT (-120.6027202 46.5965625)
# 3     POINT (-122.209285 47.71124)
# 4     POINT (-122.89692 47.043535)
# 5    POINT (-122.1713847 48.10433)
# 6     POINT (-122.111625 47.36078)
# 7     POINT (-122.151665 47.75855)
# 8  POINT (-122.6880708 48.2179983)
# 9     POINT (-122.201905 47.61385)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 2                                     PACIFICORP       5.307700e+10
# 3  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 4                         PUGET SOUND ENERGY INC       5.306701e+10
# 5                         PUGET SOUND ENERGY INC       5.306194e+10
# 6  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 7  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 8                         PUGET SOUND ENERGY INC       5.302997e+10
# 9  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.2 Understanding data

# %% [markdown]
# <m>

# %%
#report=sv.analyze(df)
#report.show_html('pPofiling Report.html')

# %%
#report=ydp.ProfileReport(df)
#report.to_file("profiling report.html")

# %%
df.shape
# Out:
# (150482, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150482 entries, 0 to 150481
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         150482 non-null  object
#  1   County                                             150479 non-null  object
#  2   City                                               150479 non-null  object
#  3   State                                              150482 non-null  object
#  4   Postal Code                                        150479 non-null  float64
#  5   Model Year                                         150482 non-null  int64
#  6   Make                                               150482 non-null  object
#  7   Model                                              150482 non-null  object
#  8   Electric Vehicle Type                              150482 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  150482 non-null  object
#  10  Electric Range                                     150482 non-null  int64
#  11  Base MSRP                                          150482 non-null  int64
#  12  Legislative District                               150141 non-null  float64
#  13  DOL Vehicle ID                                     150482 non-null  int64
#  14  Vehicle Location                                   150475 non-null  object
#  15  Electric Utility                                   150479 non-null  object
#  16  2020 Census Tract                                  150479 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 19.5+ MB

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  150479.000000  150482.000000   150482.000000  150482.000000
# mean    98168.344154    2020.005436       67.877839    1312.644735
# std      2473.612184       3.015209       96.230009    9231.310215
# min      1730.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2018.000000        0.000000       0.000000
# 50%     98122.000000    2021.000000       18.000000       0.000000
# 75%     98370.000000    2023.000000       97.000000       0.000000
# max     99577.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         150141.000000    1.504820e+05       1.504790e+05
# mean              29.343950    2.111122e+08       5.297195e+10
# std               14.824829    8.196388e+07       1.638841e+09
# min                1.000000    4.385000e+03       1.081042e+09
# 25%               18.000000    1.693473e+08       5.303301e+10
# 50%               33.000000    2.150306e+08       5.303303e+10
# 75%               43.000000    2.399119e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.603300e+10

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# Electric Utility                                      object
# 2020 Census Tract                                    float64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150482, step=1)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 341
# DOL Vehicle ID                                         0
# Vehicle Location                                       7
# Electric Utility                                       3
# 2020 Census Tract                                      3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.3 Preparing data

# %% [markdown]
# <m>

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df=df[['VIN (1-10)', 'County', 'City', 'State', 
       #'Postal Code', 
       'Model Year',
       'Make', 'Model', 'Electric Vehicle Type',
       'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 
       'Electric Range',
       'Base MSRP', 
       #'Legislative District', 
       'DOL Vehicle ID',
      # 'Vehicle Location', 'Electric Utility', '2020 Census Tract'
      ]].copy()

# %%
df.rename(columns={'VIN (1-10)':'VIN','Make':'Company','Electric Vehicle Type':'Type','Base MSRP':'Price','Electric Range':'Electric Range Miles','DOL Vehicle ID':'Vehicle ID'},inplace=True)

# %%
new_order=['VIN','Vehicle ID','Company','Model','Model Year','Electric Range Miles','Type','Clean Alternative Fuel Vehicle (CAFV) Eligibility','Price','County','City','State']

# %%
df=df[new_order]

# %%
df=df.clean_names()

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.3.1 Dealing with nulls

# %% [markdown]
# <m>

# %% [markdown]
# <m>

# %%
msno.bar(df)
plt.show()

# %%
df.isnull().sum()
# Out:
# vin                                                0
# vehicle_id                                         0
# company                                            0
# model                                              0
# model_year                                         0
# electric_range_miles                               0
# type                                               0
# clean_alternative_fuel_vehicle_cafv_eligibility    0
# price                                              0
# county                                             3
# city                                               3
# state                                              0
# dtype: int64

# %%
df.query('county.isnull()')
# Out:
#                vin  vehicle_id company     model  model_year  \
# 133103  5YJRE11B48   143609049   TESLA  ROADSTER        2008
# 136622  5YJ3E1EA5K   475254825   TESLA   MODEL 3        2019
# 140136  1N4AZ0CP1D   112277063  NISSAN      LEAF        2013
#
#         electric_range_miles                            type  \
# 133103                   220  Battery Electric Vehicle (BEV)
# 136622                   220  Battery Electric Vehicle (BEV)
# 140136                    75  Battery Electric Vehicle (BEV)
#
#        clean_alternative_fuel_vehicle_cafv_eligibility  price county city  \
# 133103         Clean Alternative Fuel Vehicle Eligible  98950    NaN  NaN
# 136622         Clean Alternative Fuel Vehicle Eligible      0    NaN  NaN
# 140136         Clean Alternative Fuel Vehicle Eligible      0    NaN  NaN
#
#        state
# 133103    BC
# 136622    BC
# 140136    AP

# %%
df=df.dropna(subset=['county','state'])

# %%
df=df[df['price']!=0]

# %%
df=df[df['electric_range_miles']!=0]

# %%
df['price'].unique()
# Out:
# array([ 69900,  31950,  52900,  32250,  90700,  54950,  36900,  59900,
#         45600,  52650,  39995,  53400,  64950,  33950, 102000,  75095,
#        110950,  44100,  81100, 184400,  36800,  43700,  55700,  34995,
#         91250, 109000,  98950,  89100,  32995, 845000], dtype=int64)

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.3.2 Dealing with outliers

# %% [markdown]
# ##### Z-Score and IQR

# %% [markdown]
# <m>

# %%
for column in ['price','electric_range_miles']: 
      sns.boxplot(df[column])
      plt.title(f'Box plot of {column}')
      plt.show()

# %%
for column in[ 'electric_range_miles','price']:
    sns.histplot(df[column],kde=True)
    plt.title(f'Distribution of {column}')
    plt.ylabel('Frequancy')
    plt.show()

# %%
df[['electric_range_miles','price']].skew()
# Out:
# electric_range_miles    -0.064238
# price                   12.556363
# dtype: float64

# %% [markdown]
# <m>

# %% [markdown]
# ##### Z-score for Electric Range (M) With Skewness -0.064

# %% [markdown]
# <m>

# %%
def calculate_upper_limit(column):
    upper_limit=column.mean()+3*column.std()
    return upper_limit

# %%
def calculate_lower_limit(column):
    lower_limit=column.mean()-3*column.std()
    return lower_limit

# %%
upper_limit=calculate_upper_limit(df['electric_range_miles'])
lower_limit=calculate_lower_limit(df['electric_range_miles'])
print(f"Upper Limit = {upper_limit}\n Lower Limit = {lower_limit}")
# Out:
# Upper Limit = 392.3413314055947
#  Lower Limit = -145.33843621161668

# %%
def z_score_outliers(df, column):
    upper_limit = df[column].mean() + 3 * df[column].std()
    lower_limit = df[column].mean() - 3 * df[column].std()
    return df[(df[column] > upper_limit) | (df[column] < lower_limit)]

# %%
outliers=z_score_outliers(df,'electric_range_miles')
outliers
# Out:
# Empty DataFrame
# Columns: [vin, vehicle_id, company, model, model_year, electric_range_miles, type, clean_alternative_fuel_vehicle_cafv_eligibility, price, county, city, state]
# Index: []

# %%
df.query('`electric_range_miles` >= 392')
# Out:
# Empty DataFrame
# Columns: [vin, vehicle_id, company, model, model_year, electric_range_miles, type, clean_alternative_fuel_vehicle_cafv_eligibility, price, county, city, state]
# Index: []

# %%
df['electric_range_miles'].max()
# Out:
# 265

# %% [markdown]
# <M>

# %% [markdown]
# ##### IQR For price With Skewness 12

# %% [markdown]
# <M>

# %%
def IQR_outliers(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    upper_bound=Q3+1.5*IQR
    lower_bound=Q1-1.5*IQR
    pd.set_option('display.max_rows',None)
    return df[(df[column]>upper_bound) | (df[column]<lower_bound)]
    
outliers= IQR_outliers(df,'price')    
outliers
# Out:
#                vin  vehicle_id  company     model  model_year  \
# 4915    WP0AH2A71J   107105750  PORSCHE  PANAMERA        2018
# 7641    WP0AH2A70J   113244169  PORSCHE  PANAMERA        2018
# 17259   WP0AH2A73J   183245247  PORSCHE  PANAMERA        2018
# 28998   WP0CH2A75J   254562381  PORSCHE  PANAMERA        2018
# 30119   WP0AH2A7XJ   475425590  PORSCHE  PANAMERA        2018
# 50136   WP0CA2A13F   100479039  PORSCHE       918        2015
# 60032   WP0AH2A74J   145752232  PORSCHE  PANAMERA        2018
# 63365   WP0CH2A76J   103328963  PORSCHE  PANAMERA        2018
# 84487   WP0AH2A76J   277238377  PORSCHE  PANAMERA        2018
# 128864  WP0AH2A77J   275095369  PORSCHE  PANAMERA        2018
# 129650  WP0AH2A7XJ   144596238  PORSCHE  PANAMERA        2018
# 131856  WP0AH2A7XJ   177769875  PORSCHE  PANAMERA        2018
#
#         electric_range_miles                                    type  \
# 4915                      14  Plug-in Hybrid Electric Vehicle (PHEV)
# 7641                      14  Plug-in Hybrid Electric Vehicle (PHEV)
# 17259                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 28998                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 30119                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 50136                     12  Plug-in Hybrid Electric Vehicle (PHEV)
# 60032                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 63365                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 84487                     14  Plug-in Hybrid Electric Vehicle (PHEV)
# 128864                    14  Plug-in Hybrid Electric Vehicle (PHEV)
# 129650                    14  Plug-in Hybrid Electric Vehicle (PHEV)
# 131856                    14  Plug-in Hybrid Electric Vehicle (PHEV)
#
#        clean_alternative_fuel_vehicle_cafv_eligibility   price     county  \
# 4915             Not eligible due to low battery range  184400      Clark
# 7641             Not eligible due to low battery range  184400       King
# 17259            Not eligible due to low battery range  184400      Clark
# 28998            Not eligible due to low battery range  184400       King
# 30119            Not eligible due to low battery range  184400       King
# 50136            Not eligible due to low battery range  845000       King
# 60032            Not eligible due to low battery range  184400      Clark
# 63365            Not eligible due to low battery range  184400       King
# 84487            Not eligible due to low battery range  184400       King
# 128864           Not eligible due to low battery range  184400   Thurston
# 129650           Not eligible due to low battery range  184400  Snohomish
# 131856           Not eligible due to low battery range  184400     Pierce
#
#                  city state
# 4915    Brush Prairie    WA
# 7641         Bellevue    WA
# 17259       Vancouver    WA
# 28998       Sammamish    WA
# 30119            Kent    WA
# 50136     Hunts Point    WA
# 60032       Vancouver    WA
# 63365   Mercer Island    WA
# 84487     Woodinville    WA
# 128864          Lacey    WA
# 129650   Lake Stevens    WA
# 131856     Gig Harbor    WA

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.3.3 Formatting and adding columns

# %% [markdown]
# <m>

# %%
df.dtypes
# Out:
# vin                                                object
# vehicle_id                                          int64
# company                                            object
# model                                              object
# model_year                                          int64
# electric_range_miles                                int64
# type                                               object
# clean_alternative_fuel_vehicle_cafv_eligibility    object
# price                                               int64
# county                                             object
# city                                               object
# state                                              object
# dtype: object

# %% [markdown]
# <m>

# %%
df.head()
# Out:
#             vin  vehicle_id company    model  model_year  \
# 68   5YJSA1CG3D   113783820   TESLA  MODEL S        2013
# 70   5YJSA1DP8D   111162012   TESLA  MODEL S        2013
# 90   5YJSA1S10E   184590640   TESLA  MODEL S        2014
# 143  KNDJX3AE6G   349107580     KIA     SOUL        2016
# 149  KNDJX3AE5G     3545412     KIA     SOUL        2016
#
#      electric_range_miles                            type  \
# 68                    208  Battery Electric Vehicle (BEV)
# 70                    208  Battery Electric Vehicle (BEV)
# 90                    208  Battery Electric Vehicle (BEV)
# 143                    93  Battery Electric Vehicle (BEV)
# 149                    93  Battery Electric Vehicle (BEV)
#
#     clean_alternative_fuel_vehicle_cafv_eligibility  price     county  \
# 68          Clean Alternative Fuel Vehicle Eligible  69900       King
# 70          Clean Alternative Fuel Vehicle Eligible  69900  Snohomish
# 90          Clean Alternative Fuel Vehicle Eligible  69900     Kitsap
# 143         Clean Alternative Fuel Vehicle Eligible  31950       King
# 149         Clean Alternative Fuel Vehicle Eligible  31950       King
#
#          city state
# 68    Seattle    WA
# 70   Stanwood    WA
# 90   Kingston    WA
# 143  Bellevue    WA
# 149   Seattle    WA

# %%
df['clean_alternative_fuel_vehicle_cafv_eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range'], dtype=object)

# %%
df['clean_alternative_fuel_vehicle_cafv_eligibility'].replace('Clean Alternative Fuel Vehicle Eligible','Eligible',inplace=True)

# %%
df['clean_alternative_fuel_vehicle_cafv_eligibility'].replace('Not eligible due to low battery range','Not Eligible',inplace=True)

# %%
df.describe()
# Out:
#          vehicle_id   model_year  electric_range_miles          price
# count  3.454000e+03  3454.000000           3454.000000    3454.000000
# mean   2.068718e+08  2015.554140            123.501448   57159.946439
# std    9.923586e+07     2.460895             89.613295   22755.027382
# min    8.981300e+04  2008.000000             12.000000   31950.000000
# 25%    1.431019e+08  2013.000000             17.000000   39995.000000
# 50%    1.930646e+08  2016.000000             93.000000   59900.000000
# 75%    2.445399e+08  2018.000000            208.000000   69900.000000
# max    4.788591e+08  2020.000000            265.000000  845000.000000

# %% [markdown]
# Price Status

# %%
df['price_status']='undefiend'

# %%
for index,row in df.iterrows():
    if row['price']<=50000:
        df.loc[index,"price_status"]="Economy"
    elif  row['price'] > 50000 and  row['price'] <=80000:
        df.loc[index,"price_status"]="Mid-Range"
    elif 80000 < row['price'] <=150000:
        df.loc[index,"price_status"]="Luxury"
    elif row['price'] >150000:
        df.loc[index,"price_status"]="Super-Luxury"

# %% [markdown]
# <m>

# %% [markdown]
# ### 1.4 Understanding features

# %% [markdown]
# <m>

# %% [markdown]
# #### (Univariant analysis)

# %% [markdown]
# <m>

# %% [markdown]
# ##### Distribution of features

# %%
df.columns
# Out:
# Index(['vin', 'vehicle_id', 'company', 'model', 'model_year',
#        'electric_range_miles', 'type',
#        'clean_alternative_fuel_vehicle_cafv_eligibility', 'price', 'county',
#        'city', 'state', 'price_status'],
#       dtype='object')

# %%
for column in ['company', 'model', 'model_year', 'type','clean_alternative_fuel_vehicle_cafv_eligibility','county','city', 'state', 'price_status']:
    ax=df[column].value_counts().plot(kind='bar',title=(f'Distribution of {column}'))
    ax.set_xlabel(f'{column}')
    ax.set_ylabel('Frequancy')
    plt.show()

# %%
for column in ['price','electric_range_miles']:
       ax=df['price'].plot(kind='kde',title=('Distribution of price'))
       ax.set_xlabel(f'{column}')
       ax.set_ylabel('Frequancy')
       plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ## 2. Analyzing Data

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.1 Heatmap

# %% [markdown]
# <m>

# %%
numeric_columns=df.select_dtypes(include='number')

# %%
corr1=numeric_columns.corr()

# %%
corr1
# Out:
#                       vehicle_id  model_year  electric_range_miles     price
# vehicle_id              1.000000    0.243999             -0.223787 -0.125693
# model_year              0.243999    1.000000             -0.930991 -0.469196
# electric_range_miles   -0.223787   -0.930991              1.000000  0.407551
# price                  -0.125693   -0.469196              0.407551  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(corr1,annot=True,vmax=1,vmin=-1,center=0,fmt='.1f',cmap='Purples',edgecolor='k',linewidth=1)
plt.title('Electric vehicle heatmap',fontfamily='times new roman',fontsize=15,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# <M>

# %% [markdown]
# ### 2.2 Counties with the most e-cars

# %% [markdown]
# <m>

# %%
Country_m=df.groupby('county').size().sort_values(ascending=False).head(10)
Country_m
# Out:
# county
# King         1807
# Snohomish     352
# Pierce        299
# Clark         182
# Kitsap        143
# Whatcom       106
# Thurston      103
# Spokane        78
# Skagit         46
# Island         42
# dtype: int64

# %%
sns.barplot(x=Country_m.values,y=Country_m.index,edgecolor="k",palette='twilight')
plt.title('Counties with the most e-cars')
plt.xlabel("No. Of E-Cars")
plt.ylabel('County')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.3 Counties that doesn't prefer e-cars

# %% [markdown]
# <m>

# %%
df.groupby("county").size().sort_values(ascending=True).head(18)
# Out:
# county
# Burlington      1
# Charles         1
# Ulster          1
# Columbia        1
# Contra Costa    1
# Rock Island     1
# Riverside       1
# Multnomah       1
# Los Angeles     1
# Williamson      1
# Asotin          2
# Whitman         2
# Wahkiakum       2
# Skamania        2
# Lincoln         2
# Klickitat       3
# Stevens         3
# Okanogan        4
# dtype: int64

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.4 States e-cars population

# %% [markdown]
# <m>

# %%
state_m=df.groupby("state").size().sort_values(ascending=False).head(10)
state_m
# Out:
# state
# WA    3445
# CA       3
# IL       1
# MD       1
# NJ       1
# NY       1
# OR       1
# TX       1
# dtype: int64

# %%
sns.barplot(x=state_m.values,y=state_m.index,edgecolor='k',palette='twilight')
plt.xscale('log', base=4)
plt.title('States e-cars population')
plt.xlabel("No of e-cars")
plt.ylabel('State')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.5 Cities with the most e-cars

# %% [markdown]
# <m>

# %%
city_m=df.groupby("city").size().sort_values(ascending=False).head(10)
city_m
# Out:
# city
# Seattle        573
# Bellevue       198
# Kirkland       123
# Redmond        114
# Vancouver      110
# Sammamish      106
# Renton          82
# Tacoma          77
# Olympia         74
# Woodinville     70
# dtype: int64

# %%
sns.barplot(x=city_m.values,y=city_m.index,edgecolor="k",palette='twilight')
plt.title('Cities with the most e-cars')
plt.xlabel("No.of e-cars")
plt.ylabel('City')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.6 Cities that doesn't prefer e-cars

# %% [markdown]
# <m>

# %%
print(df.groupby("city").size().sort_values().head(100).to_string())
# Out:
# city
# Zillah             1
# Easton             1
# Tokeland           1
# Tonasket           1
# Reardan            1
# Touchet            1
# Deming             1
# Tenino             1
# Dayton             1
# Custer             1
# Randle             1
# Milton             1
# Hoodsport          1
# Montesano          1
# Clarkston          1
# Davenport          1
# Rock Island        1
# Surfside           1
# Edwall             1
# Indio              1
# Snoqualmie Pass    1
# Pittsburg          1
# La Center          1
# La Conner          1
# Stevenson          1
# Round Rock         1
# Roslyn             1
# Lilliwaup          1
# Longbranch         1
# Los Angeles        1
# Lumberton          1
# Lyle               1
# Suquamish          1
# Elma               1
# Clallam Bay        1
# Chewelah           1
# Hughesville        1
# Quincy             1
# Peshastin          1
# Pateros            1
# Palouse            1
# Ariel              1
# Asotin             1
# Baring             1
# Oroville           1
# Beaux Arts         1
# Onalaska           1
# Winthrop           1
# Benton City        1
# Olga               1
# Westport           1
# Bow                1
# Wilkeson           1
# Port Ludlow        1
# Moxee              1
# Portland           1
# Quilcene           1
# Naches             1
# Pullman            1
# Waitsburg          1
# Underwood          1
# Vaughn             1
# Ocean Park         1
# Union              1
# Pacific            2
# Lakebay            2
# Othello            2
# Orting             2
# Raymond            2
# Lopez Island       2
# Newman Lake        2
# Medical Lake       2
# Port Hadlock       2
# Ronald             2
# Malaga             2
# Mossyrock          2
# Nine Mile Falls    2
# Maple Falls        2
# Olalla             2
# Long Beach         2
# Rainier            2
# Grapeview          2
# Greenbank          2
# Clinton            2
# Eatonville         2
# Centralia          2
# Cathlamet          2
# Woodway            2
# White Salmon       2
# Hunts Point        2
# Allyn              2
# Yacolt             2
# Anderson Island    3
# Cheney             3
# Chelan             3
# Greenacres         3
# Silverlake         3
# Sunnyside          3
# Sumner             3
# Castle Rock        3

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.7 Company with the most e-cars production

# %% [markdown]
# <m>

# %%
company_mp=df.groupby("company").size().sort_values(ascending=False).head(10)
company_mp
# Out:
# company
# TESLA       1621
# KIA          625
# BMW          506
# VOLVO        301
# MINI         154
# CHRYSLER     117
# SUBARU        64
# PORSCHE       31
# FISKER        17
# CADILLAC      15
# dtype: int64

# %%
sns.barplot(x=company_mp.values,y=company_mp.index,edgecolor="k",palette='twilight')
plt.title("Company with the most e-cars production",fontfamily="times new roman")
plt.xlabel("No. of e-cars")
plt.ylabel('Company')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.8 Company with the highest sales

# %% [markdown]
# <m>

# %%
company_s=df.groupby('company').price.sum().sort_values(ascending=False).head(10)
company_s
# Out:
# company
# TESLA       113626550
# BMW          26748400
# KIA          20162350
# VOLVO        16923050
# MINI          5677300
# CHRYSLER      4679415
# PORSCHE       4414300
# SUBARU        2239680
# FISKER        1734000
# CADILLAC      1126425
# Name: price, dtype: int64

# %%
sns.barplot(x=company_s.values,y=company_s.index,edgecolor='k',palette='twilight')
plt.title('Company with the highest sales',fontfamily='times new roman')
plt.xlabel('Sales')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.10 Company with the most expensive e-cars

# %% [markdown]
# <m>

# %%
company_high_p=df.groupby('company').price.max().sort_values(ascending=False).head(10)
company_high_p
# Out:
# company
# PORSCHE     845000
# TESLA       110950
# FISKER      102000
# BMW          91250
# CADILLAC     75095
# VOLVO        64950
# CHRYSLER     39995
# MINI         36900
# SUBARU       34995
# KIA          33950
# Name: price, dtype: int64

# %%
sns.barplot(x=company_high_p.values,y=company_high_p.index,edgecolor="k",palette='twilight')
plt.title("Brands with the most expensive e-cars",fontfamily="times new roman")
plt.xlabel("Prices")
plt.ylabel('Company')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <M>

# %% [markdown]
# ### 2.11 Models with the highest sales

# %% [markdown]
# <m>

# %%
Model_s=df.groupby('model').price.sum().sort_values(ascending=False).head(10)
Model_s
# Out:
# model
# MODEL S       108752500
# 530E           15489150
# SOUL           12748050
# XC60           11532200
# 330E            8545100
# SOUL EV         7414300
# COUNTRYMAN      5677300
# XC90            5390850
# ROADSTER        4874050
# PACIFICA        4679415
# Name: price, dtype: int64

# %%
sns.barplot(x=Model_s.values,y=Model_s.index,edgecolor="k",palette='twilight')
plt.title("Models with the highest sales ",fontfamily="times new roman")
plt.xlabel("Sales")
plt.ylabel('Model')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.12 Models with the lowest sales

# %% [markdown]
# <m>

# %%
Model_sl=df.groupby('model').price.sum().sort_values(ascending=True).head(10)
Model_sl
# Out:
# model
# WHEEGO         98985
# 918           845000
# CT6          1126425
# CAYENNE      1540900
# KARMA        1734000
# PANAMERA     2028400
# CROSSTREK    2239680
# 740E         2714150
# PACIFICA     4679415
# ROADSTER     4874050
# Name: price, dtype: int64

# %%
sns.barplot(x=Model_sl.values,y=Model_sl.index,edgecolor="k",palette='twilight')
plt.title("models with the lowest sales ",fontfamily="times new roman")
plt.xlabel("Sales")
plt.ylabel('Model')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.13 Most expinsive e-cars models

# %% [markdown]
# <m>

# %%
Model_e=df.groupby('model').price.max().sort_values(ascending=False).head(10)
Model_e
# Out:
# model
# 918         845000
# PANAMERA    184400
# ROADSTER    110950
# KARMA       102000
# 740E         91250
# CAYENNE      81100
# CT6          75095
# MODEL S      69900
# XC90         64950
# 530E         55700
# Name: price, dtype: int64

# %%
sns.barplot(x=Model_e.values,y=Model_e.index,edgecolor="k",palette='twilight')
plt.title(" Most expinsive e-cars models",fontfamily="times new roman")
plt.xlabel("Price")
plt.ylabel('Model')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.14 Cheapiest e-cars models

# %% [markdown]
# <m>

# %%
Model_c=df.groupby('model').price.max().sort_values(ascending=True).head(10)
Model_c
# Out:
# model
# SOUL          31950
# WHEEGO        32995
# SOUL EV       33950
# CROSSTREK     34995
# COUNTRYMAN    36900
# PACIFICA      39995
# 330E          45600
# XC60          52900
# 530E          55700
# XC90          64950
# Name: price, dtype: int64

# %%
sns.barplot(x=Model_c.values,y=Model_c.index,edgecolor="k",palette='twilight')
plt.title("Cheapiest e-cars models",fontfamily="times new roman")
plt.xlabel("Price")
plt.ylabel('Model')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.15 Most powerfule e-cars

# %% [markdown]
# <m>

# %%
model_p=df.groupby('model')['electric_range_miles'].max().sort_values(ascending=False).head(10)
model_p
# Out:
# model
# MODEL S      265
# ROADSTER     245
# SOUL EV      111
# WHEEGO       100
# SOUL          93
# KARMA         33
# PACIFICA      32
# CT6           31
# XC90          19
# CROSSTREK     17
# Name: electric_range_miles, dtype: int64

# %%
sns.barplot(x=model_p.values,y=model_p.index,edgecolor="k",palette='twilight')
plt.title("Most powerfule e-cars",fontfamily="times new roman")
plt.xlabel("Electric Range (Miles)")
plt.ylabel('Model')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.16 Least powerful e-cars

# %% [markdown]
# <m>

# %%
model_pl=df.groupby('model')['electric_range_miles'].max().sort_values(ascending=True).head(9)
model_pl
# Out:
# model
# 918           12
# COUNTRYMAN    12
# 330E          14
# 740E          14
# CAYENNE       14
# PANAMERA      14
# 530E          16
# CROSSTREK     17
# XC60          17
# Name: electric_range_miles, dtype: int64

# %%
sns.barplot(x=model_pl.values,y=model_pl.index,edgecolor="k",palette='twilight')
plt.title("Least powerfule e-cars",fontfamily="times new roman")
plt.xlabel("Electric Range (Miles)")
plt.ylabel('Model')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.17 Type analysis

# %% [markdown]
# <m>

# %%
type_n=df.groupby('type').vin.count().sort_values(ascending=False)
type_p=df.groupby('type').price.sum().sort_values(ascending=False)
type_pow=df.groupby('type')['electric_range_miles'].sum().sort_values(ascending=False)

# %%
type_n
# Out:
# type
# Battery Electric Vehicle (BEV)            2246
# Plug-in Hybrid Electric Vehicle (PHEV)    1208
# Name: vin, dtype: int64

# %%
type_p
# Out:
# type
# Battery Electric Vehicle (BEV)            133788900
# Plug-in Hybrid Electric Vehicle (PHEV)     63641555
# Name: price, dtype: int64

# %%
type_pow
# Out:
# type
# Battery Electric Vehicle (BEV)            405515
# Plug-in Hybrid Electric Vehicle (PHEV)     21059
# Name: electric_range_miles, dtype: int64

# %%
summary_df=pd.concat([type_p,type_pow,type_n],axis=1).reset_index().rename(columns={'index':'type'})
melted_df=summary_df.melt(id_vars='type',value_vars=['price','electric_range_miles','vin'],var_name='Metric',value_name='value')

# %%
summary_df
# Out:
#                                      type      price  electric_range_miles  \
# 0          Battery Electric Vehicle (BEV)  133788900                405515
# 1  Plug-in Hybrid Electric Vehicle (PHEV)   63641555                 21059
#
#     vin
# 0  2246
# 1  1208

# %%
melted_df
# Out:
#                                      type                Metric      value
# 0          Battery Electric Vehicle (BEV)                 price  133788900
# 1  Plug-in Hybrid Electric Vehicle (PHEV)                 price   63641555
# 2          Battery Electric Vehicle (BEV)  electric_range_miles     405515
# 3  Plug-in Hybrid Electric Vehicle (PHEV)  electric_range_miles      21059
# 4          Battery Electric Vehicle (BEV)                   vin       2246
# 5  Plug-in Hybrid Electric Vehicle (PHEV)                   vin       1208

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="type",y="value",hue="Metric",data=melted_df,edgecolor="k", palette="twilight",width=0.5)
plt.yscale('log')
plt.title("Type analysis",fontfamily="times new roman",fontsize=15,fontweight="bold")
plt.xlabel("Type")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.18 CAFV analysis

# %% [markdown]
# <m>

# %%
df.columns
# Out:
# Index(['vin', 'vehicle_id', 'company', 'model', 'model_year',
#        'electric_range_miles', 'type',
#        'clean_alternative_fuel_vehicle_cafv_eligibility', 'price', 'county',
#        'city', 'state', 'price_status'],
#       dtype='object')

# %%
cafv_n=df.groupby("clean_alternative_fuel_vehicle_cafv_eligibility").vin.count().sort_values(ascending=False)
cafv_p=df.groupby('clean_alternative_fuel_vehicle_cafv_eligibility').price.sum().sort_values(ascending=False)
cafv_pow=df.groupby('clean_alternative_fuel_vehicle_cafv_eligibility')['electric_range_miles'].sum().sort_values(ascending=False)

# %%
cafv_n
# Out:
# clean_alternative_fuel_vehicle_cafv_eligibility
# Eligible        2398
# Not Eligible    1056
# Name: vin, dtype: int64

# %%
cafv_p
# Out:
# clean_alternative_fuel_vehicle_cafv_eligibility
# Eligible        141427725
# Not Eligible     56002730
# Name: price, dtype: int64

# %%
cafv_pow
# Out:
# clean_alternative_fuel_vehicle_cafv_eligibility
# Eligible        410585
# Not Eligible     15989
# Name: electric_range_miles, dtype: int64

# %%
summary_df=pd.concat([cafv_p,cafv_pow,cafv_n],axis=1).reset_index().rename(columns={'index':'clean_alternative_fuel_vehicle_cafv_eligibility'})
melted_df=summary_df.melt(id_vars='clean_alternative_fuel_vehicle_cafv_eligibility',value_vars=['price','electric_range_miles','vin'],var_name='Metric',value_name='Value')

# %%
summary_df
# Out:
#   clean_alternative_fuel_vehicle_cafv_eligibility      price  \
# 0                                        Eligible  141427725
# 1                                    Not Eligible   56002730
#
#    electric_range_miles   vin
# 0                410585  2398
# 1                 15989  1056

# %%
melted_df
# Out:
#   clean_alternative_fuel_vehicle_cafv_eligibility                Metric  \
# 0                                        Eligible                 price
# 1                                    Not Eligible                 price
# 2                                        Eligible  electric_range_miles
# 3                                    Not Eligible  electric_range_miles
# 4                                        Eligible                   vin
# 5                                    Not Eligible                   vin
#
#        Value
# 0  141427725
# 1   56002730
# 2     410585
# 3      15989
# 4       2398
# 5       1056

# %%
sns.barplot(x='Value',y='clean_alternative_fuel_vehicle_cafv_eligibility',hue='Metric',data=melted_df,width=0.5,edgecolor='k',palette="twilight")
plt.title('CAFV analysis',fontfamily='times new roman')
plt.xlabel('Values')
plt.ylabel('CAFV Eligibilty')
plt.xscale('log')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.19 Price status analysis

# %% [markdown]
# <m>

# %%
ps_n=df.groupby('price_status').vin.count().sort_values(ascending=False)
ps_p=df.groupby('price_status').price.sum().sort_values(ascending=False)
ps_pow=df.groupby('price_status')['electric_range_miles'].sum().sort_values(ascending=False)

# %%
ps_n
# Out:
# price_status
# Mid-Range       2176
# Economy         1154
# Luxury           112
# Super-Luxury      12
# Name: vin, dtype: int64

# %%
ps_p
# Out:
# price_status
# Mid-Range       142291125
# Economy          41402830
# Luxury           10863100
# Super-Luxury      2873400
# Name: price, dtype: int64

# %%
ps_pow
# Out:
# price_status
# Mid-Range       345230
# Economy          69111
# Luxury           12067
# Super-Luxury       166
# Name: electric_range_miles, dtype: int64

# %%
summary_df=pd.concat([ps_p,ps_pow,ps_n],axis=1).reset_index().rename(columns={'index':'price_status'})
melted_df=summary_df.melt(id_vars='price_status',value_vars=['price','electric_range_miles','vin'],var_name='Metric',value_name='Value')

# %%
summary_df
# Out:
#    price_status      price  electric_range_miles   vin
# 0     Mid-Range  142291125                345230  2176
# 1       Economy   41402830                 69111  1154
# 2        Luxury   10863100                 12067   112
# 3  Super-Luxury    2873400                   166    12

# %%
melted_df
# Out:
#     price_status                Metric      Value
# 0      Mid-Range                 price  142291125
# 1        Economy                 price   41402830
# 2         Luxury                 price   10863100
# 3   Super-Luxury                 price    2873400
# 4      Mid-Range  electric_range_miles     345230
# 5        Economy  electric_range_miles      69111
# 6         Luxury  electric_range_miles      12067
# 7   Super-Luxury  electric_range_miles        166
# 8      Mid-Range                   vin       2176
# 9        Economy                   vin       1154
# 10        Luxury                   vin        112
# 11  Super-Luxury                   vin         12

# %%
sns.barplot(x='Value',y='price_status',hue='Metric',data=melted_df,width=0.5,edgecolor='k',palette="twilight")
plt.title('Price status analysis',fontfamily='times new roman')
plt.xlabel('Values')
plt.ylabel('Price status')
plt.xscale('log')
plt.legend(
title="Metric",               
loc="lower left",             
bbox_to_anchor=(-0.04, -0.4),  
ncol=1,                      
frameon=True                   
)
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.20 Sales analysis

# %% [markdown]
# <m>

# %%
sns.lineplot(x='model_year',y='price',data=df,color='#43A047',marker='o')
plt.title('Sales analysis',fontfamily='times new roman')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# <m>

# %% [markdown]
# ### 2.21 Relation between power and price

# %% [markdown]
# <m>

# %%
plt.scatter(df['electric_range_miles'],df['price'],edgecolor='k',cmap='Greens',c=df['model_year'],alpha=0.6)
plt.title('Relation between power and price',fontfamily='times new roman')
plt.xlabel('Electric Range (Miles)')
plt.ylabel('Price')
plt.colorbar(label='Model year')
plt.show()
